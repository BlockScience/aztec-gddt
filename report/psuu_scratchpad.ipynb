# %%
# Import statements 
# 
import os
os.chdir("..")

import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import seaborn as sns

from aztec_gddt.metrics import *
from aztec_gddt.plot_tools import *

# %%
# Reading data 
data = pd.read_pickle("data/simulations/sim_df.pkl.zip")

# %%
processed_data = process_df(data)
processed_data
# Out:
#          time_l1  delta_l1_blocks  advance_l1_blocks  \
# 1            1.0              0.0                0.0
# 2            2.0              0.0                0.0
# 3            3.0              0.0                0.0
# 4            4.0              0.0                0.0
# 5            5.0              0.0                0.0
# ...          ...              ...                ...
# 1031988    246.0              0.0                0.0
# 1031989    247.0              0.0                0.0
# 1031990    248.0              0.0                0.0
# 1031991    249.0              0.0                0.0
# 1031999    250.0              0.0                0.0
#
#                                                     agents  \
# 1        {'relay': Agent(uuid='relay', balance=0.0, is_...
# 2        {'relay': Agent(uuid='relay', balance=0.0, is_...
# 3        {'relay': Agent(uuid='relay', balance=0.0, is_...
# 4        {'relay': Agent(uuid='relay', balance=0.0, is_...
# 5        {'relay': Agent(uuid='relay', balance=0.0, is_...
# ...                                                    ...
# 1031988  {'relay': Agent(uuid='relay', balance=0.0, is_...
# 1031989  {'relay': Agent(uuid='relay', balance=0.0, is_...
# 1031990  {'relay': Agent(uuid='relay', balance=0.0, is_...
# 1031991  {'relay': Agent(uuid='relay', balance=0.0, is_...
# 1031999  {'relay': Agent(uuid='relay', balance=0.0, is_...
#
#                                            current_process  \
# 1        Process(uuid=UUID('a8eba58f-1edc-4b0f-87c1-023...
# 2        Process(uuid=UUID('a8eba58f-1edc-4b0f-87c1-023...
# 3        Process(uuid=UUID('a8eba58f-1edc-4b0f-87c1-023...
# 4        Process(uuid=UUID('a8eba58f-1edc-4b0f-87c1-023...
# 5        Process(uuid=UUID('a8eba58f-1edc-4b0f-87c1-023...
# ...                                                    ...
# 1031988  Process(uuid=UUID('4d154126-a754-4199-a0e7-632...
# 1031989  Process(uuid=UUID('4d154126-a754-4199-a0e7-632...
# 1031990  Process(uuid=UUID('4d154126-a754-4199-a0e7-632...
# 1031991  Process(uuid=UUID('4d154126-a754-4199-a0e7-632...
# 1031999  Process(uuid=UUID('4d154126-a754-4199-a0e7-632...
#
#                                               transactions  gas_fee_l1  \
# 1                                                       {}         1.0
# 2                                                       {}         3.0
# 3        {29f2aac9-71a9-4e4c-80b9-9edd54cb7991: Proposa...         1.0
# 4        {29f2aac9-71a9-4e4c-80b9-9edd54cb7991: Proposa...         1.0
# 5        {29f2aac9-71a9-4e4c-80b9-9edd54cb7991: Proposa...         1.0
# ...                                                    ...         ...
# 1031988                                                 {}         1.0
# 1031989                                                 {}         1.0
# 1031990                                                 {}        31.0
# 1031991                                                 {}         1.0
# 1031999                                                 {}       141.0
#
#          gas_fee_blob  finalized_blocks_count  cumm_block_rewards  ...  \
# 1                 1.0                     0.0               200.0  ...
# 2                 1.0                     0.0               200.0  ...
# 3                25.0                     0.0               200.0  ...
# 4                30.0                     0.0               200.0  ...
# 5                 1.0                     0.0               200.0  ...
# ...               ...                     ...                 ...  ...
# 1031988           1.0                     0.0               200.0  ...
# 1031989           1.0                     0.0               200.0  ...
# 1031990          18.0                     0.0               200.0  ...
# 1031991           1.0                     0.0               200.0  ...
# 1031999           6.0                     0.0               200.0  ...
#
#          blob_gas_threshold_for_tx  proving_marketplace_usage_probability  \
# 1                             50.0                                    0.0
# 2                             50.0                                    0.0
# 3                             50.0                                    0.0
# 4                             50.0                                    0.0
# 5                             50.0                                    0.0
# ...                            ...                                    ...
# 1031988                       50.0                                    0.0
# 1031989                       50.0                                    0.0
# 1031990                       50.0                                    0.0
# 1031991                       50.0                                    0.0
# 1031999                       50.0                                    0.0
#
#         rewards_to_provers  rewards_to_relay  gwei_to_tokens  \
# 1                      0.5               0.0    1.000000e-09
# 2                      0.5               0.0    1.000000e-09
# 3                      0.5               0.0    1.000000e-09
# 4                      0.5               0.0    1.000000e-09
# 5                      0.5               0.0    1.000000e-09
# ...                    ...               ...             ...
# 1031988                0.5               0.0    1.000000e-09
# 1031989                0.5               0.0    1.000000e-09
# 1031990                0.5               0.0    1.000000e-09
# 1031991                0.5               0.0    1.000000e-09
# 1031999                0.5               0.0    1.000000e-09
#
#                                               slash_params  \
# 1        SlashParameters(failure_to_commit_bond=2.0, fa...
# 2        SlashParameters(failure_to_commit_bond=2.0, fa...
# 3        SlashParameters(failure_to_commit_bond=2.0, fa...
# 4        SlashParameters(failure_to_commit_bond=2.0, fa...
# 5        SlashParameters(failure_to_commit_bond=2.0, fa...
# ...                                                    ...
# 1031988  SlashParameters(failure_to_commit_bond=2.0, fa...
# 1031989  SlashParameters(failure_to_commit_bond=2.0, fa...
# 1031990  SlashParameters(failure_to_commit_bond=2.0, fa...
# 1031991  SlashParameters(failure_to_commit_bond=2.0, fa...
# 1031999  SlashParameters(failure_to_commit_bond=2.0, fa...
#
#          commit_bond_amount  op_costs                            process_id  \
# 1                      10.0       0.0  a8eba58f-1edc-4b0f-87c1-023ee5f0f6fe
# 2                      10.0       0.0  a8eba58f-1edc-4b0f-87c1-023ee5f0f6fe
# 3                      10.0       0.0  a8eba58f-1edc-4b0f-87c1-023ee5f0f6fe
# 4                      10.0       0.0  a8eba58f-1edc-4b0f-87c1-023ee5f0f6fe
# 5                      10.0       0.0  a8eba58f-1edc-4b0f-87c1-023ee5f0f6fe
# ...                     ...       ...                                   ...
# 1031988                10.0       0.0  4d154126-a754-4199-a0e7-6329dd548d9f
# 1031989                10.0       0.0  4d154126-a754-4199-a0e7-6329dd548d9f
# 1031990                10.0       0.0  4d154126-a754-4199-a0e7-6329dd548d9f
# 1031991                10.0       0.0  4d154126-a754-4199-a0e7-6329dd548d9f
# 1031999                10.0       0.0  4d154126-a754-4199-a0e7-6329dd548d9f
#
#          process_phase
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# 5                    1
# ...                ...
# 1031988              1
# 1031989              1
# 1031990              1
# 1031991              1
# 1031999             -1
#
# [1000000 rows x 50 columns]

# %%
# Postprocessing data into a form for plotting

 #   g1_trajectory_kpis = {"proportion_race_mode" : find_proportion_race_mode,
 #                     "proportion_slashed_sequencer" : find_proportion_slashed_due_to_sequencer,
 #                     "proportion_slashed_prover" : find_proportion_slashed_due_to_prover,
 #                     "proportion_skipped" : find_proportion_skipped
 #                     }

# NOTE: Mock version for now. 
g1_trajectory_kpis = {"proportion_race_mode": mock_proportion_race_mode,
                      "proportion_slashed_sequencer": mock_proportion_slashed_due_to_sequencer,
                       "proportion_slashed_prover": mock_proportion_slashed_due_to_prover,
                       "proportion_skipped": mock_proportion_skipped}

processed_df = process_df(data)

# %%
base_df = extract_df(processed_df,
                         trajectory_kpis = g1_trajectory_kpis,
                         cols_to_drop = ['simulation', 'subset', 'run'])

# %%
create_decision_tree_importances_plot(base_df,
                                      params_to_use = governance_surface_params,
                                      kpi = "proportion_race_mode")
# Out:
# (<Figure size 3600x1200 with 2 Axes>,
#  array([<Axes: title={'center': 'Decision tree, score: 56%. N: 9.01e+02'}>,
#         <Axes: title={'center': 'Feature importance'}, xlabel='features', ylabel='importance'>],
#        dtype=object))

# %%
create_decision_tree_importances_plot(base_df,
                                      params_to_use = governance_surface_params,
                                      kpi = "proportion_skipped")
# Out:
# (<Figure size 3600x1200 with 2 Axes>,
#  array([<Axes: title={'center': 'Decision tree, score: 58%. N: 9.01e+02'}>,
#         <Axes: title={'center': 'Feature importance'}, xlabel='features', ylabel='importance'>],
#        dtype=object))

# %% [markdown]
# # Parameter Impact on KPIs

# %%
create_param_impact_dist_plots(df_to_use = base_df,
                               param_cols = governance_surface_params,
                              kpi_cols= ["proportion_race_mode", "proportion_skipped"]
                               )
# Out:
# c:\Users\andre\Desktop\aztec-gddt\aztec_gddt\plot_tools.py:78: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.kdeplot(
# c:\Users\andre\Desktop\aztec-gddt\aztec_gddt\plot_tools.py:78: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.kdeplot(
# (<Figure size 2200x400 with 22 Axes>,
#  array([[<Axes: title={'center': 'Impact of phase_duration_proposal_min_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_proposal_min_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_proposal_max_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_proposal_max_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_reveal_min_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_reveal_min_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_reveal_max_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_reveal_max_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_commit_bond_min_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_commit_bond_min_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_commit_bond_max_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_commit_bond_max_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_rollup_min_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_rollup_min_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_rollup_max_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_rollup_max_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_race_min_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_race_min_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_race_max_blocks on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_race_max_blocks on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of reward_per_block on proportion_race_mode'}, xlabel='proportion_race_mode', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of reward_per_block on proportion_skipped'}, xlabel='proportion_skipped', ylabel='Density'>]],
#        dtype=object))

# %%
create_param_impact_dist_plots(df_to_use = base_df,
                               param_cols = governance_surface_params,
                              kpi_cols= ["proportion_slashed_sequencer", 
                                         "proportion_slashed_prover"]
                               )
# Out:
# c:\Users\andre\Desktop\aztec-gddt\aztec_gddt\plot_tools.py:78: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.kdeplot(
# c:\Users\andre\Desktop\aztec-gddt\aztec_gddt\plot_tools.py:78: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.kdeplot(
# (<Figure size 2200x400 with 22 Axes>,
#  array([[<Axes: title={'center': 'Impact of phase_duration_proposal_min_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_proposal_min_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_proposal_max_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_proposal_max_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_reveal_min_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_reveal_min_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_reveal_max_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_reveal_max_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_commit_bond_min_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_commit_bond_min_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_commit_bond_max_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_commit_bond_max_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_rollup_min_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_rollup_min_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_rollup_max_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_rollup_max_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_race_min_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_race_min_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of phase_duration_race_max_blocks on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of phase_duration_race_max_blocks on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>],
#         [<Axes: title={'center': 'Impact of reward_per_block on proportion_slashed_sequencer'}, xlabel='proportion_slashed_sequencer', ylabel='Density'>,
#          <Axes: title={'center': 'Impact of reward_per_block on proportion_slashed_prover'}, xlabel='proportion_slashed_prover', ylabel='Density'>]],
#        dtype=object))

# %% [markdown]
# # Conclusion
